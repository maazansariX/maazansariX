# %% [markdown]
# <a href="https://colab.research.google.com/github/maazansariX/maazansariX/blob/main/Python_Case_Study_Business_Case_of_Aerofit_Analysis_%26_Insights_by_Maaz_Ansari.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BUSINESS CASE: **AEROFIT**
# PROJECT & INSIGHTS ON PYTHON BY: **MAAZ ANSARI**

# %% [markdown]
# **About NETFLIX**\
# Aerofit is a leading brand in the field of fitness equipment. Aerofit provides a product range including machines such as treadmills, exercise bikes, gym equipment, and fitness accessories to cater to the needs of all categories of people.
#
# **Business Problem by Scaler & Solution by Maaz Ansari**\
# The market research team at AeroFit wants to identify the characteristics of the target audience for each type of treadmill offered by the company, to provide a better recommendation of the treadmills to the new customers. The team decides to investigate whether there are differences across the product with respect to customer characteristics.
#   1.	Perform descriptive analytics to create a customer profile for each AeroFit treadmill product by developing appropriate tables and charts.
#   2.	For each AeroFit treadmill product, construct two-way contingency tables and compute all conditional and marginal probabilities along with their insights/impact on the business.

# %% [markdown]
# # Dataset
# The company collected the data on individuals who purchased a treadmill from the AeroFit stores during the prior three months. The dataset has the following features:
#
# Dataset link: https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/001/125/original/aerofit_treadmill.csv?1639992749

# %% [markdown]
# ## **Schema of Data:**
#
# * **Product Purchased** : KP281, KP481, or KP781
# * **Age**		            : In years
# * **Gender**		        : Male/Female
# * **Education**	        : In years
# * **MaritalStatus**	    : Single or partnered
# * **Usage**	            : The average number of times the customer plans to use the treadmill each week.
# * **Income**	          : Annual income (in $)
# * **Fitness**           : Self-rated fitness on a 1-to-5 scale, where 1 is the poor shape and 5 is the excellent shape.
# * **Miles**	  	        : The average number of miles the customer expects to walk/run each week
#
#
# # **Product Portfolio:**
#
# 1.The KP281 is an entry-level treadmill that sells for $1,500.
#
# 2.The KP481 is for mid-level runners that sell for $1,750.
#
# 3.The KP781 treadmill is having advanced features that sell for $2,500.

# %%
"Step1: Importing Python Libraries Aerofit Business Case"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
"Step 2: Upload of Aerofit_Treadmill Data - Provided by Scaler"

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7d6c7e51-86ef-44fd-bf95-88fd1588d648" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7d6c7e51-86ef-44fd-bf95-88fd1588d648">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
"Step 3: Read Aerofit_Treadmill data"

# %%
aerofit = pd.read_csv("aerofit_treadmill.csv")

# %% [markdown]
# # 1.	Import the dataset and do usual data analysis steps like checking the structure & characteristics of the dataset

# %%
"Step 4: Review Header Data to check Upload and Read success"

# %%
aerofit.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %%
#Raw Data Insights: Aerofit data has 9 columns detailing about Aerofit Treadmill sales.

# %%
"Step 5: Analyze the amount of Numerical Data from the given dataset"

# %%
aerofit.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
#Describe function is used to check on Numerical values.

# %%
"Step 6: Understand the depth of data into Rows,Columns"

# %%
aerofit.shape
# Out:
# (180, 9)

# %%
print(f"Number of rows: {aerofit.shape[0]}\nNumber of columns: {aerofit.shape[1]}")
# Out:
# Number of rows: 180
# Number of columns: 9

# %%
#As per above tuple, it is clear that Total no. of Rows is spread across 180 Row items and 9 Columns

# %%
"Step 7: To understhand the data type of each column to clean, modify and analyze"

# %%
aerofit.dtypes
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %%
# Categorical columns are defined by dtype: object(str) and numerical columns are defined by dtype: int64(integer)

# %%
"Step 8: To understhand the data type of each column to clean, modify and analyze"

# %%
aerofit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
# Above insight is quite useful to check Non-Null values along with data type.

# %%
"Step 9: Duplicate check"

# %%
aerofit[aerofit.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Product, Age, Gender, Education, MaritalStatus, Usage, Fitness, Income, Miles]
# Index: []

# %%
# No duplicates detected.

# %%
"Step 10: Missing Values check in columns"

# %%
aerofit.isna().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
# There are no null values in any column.

# %%
"Step 11: Macro observations"

# %% [markdown]
# # 2.	Detect Outliers (using boxplot, “describe” method by checking the difference between mean and median)

# %%
aerofit.describe(include = "all")
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      KP281         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %%
# OBSERVATIONS:
# 1. There are 3 unique products in the dataset.
# 2. KP281 is the most popular produce in the dataset which is the least costliest.
# 3. Min & Max ages are 18 & 50, Mean is 28.7 and 75% of people are less than or equal to 33 years.
# 4. Data is more male biased as there 104 males and remaining females.
# 5. Education leve is of 16 years for most of the people.
# 6. Standard deviation for Miles & Income is very high. These variables might have the outliers in it.

# %%
"Step 11: Unique Products"

# %%
aerofit["Product"].unique()
# Out:
# array(['KP281', 'KP481', 'KP781'], dtype=object)

# %%
# Three unique products are KP281, KP481, KP781

# %% [markdown]
# ## **REVIEW AND ANALYSIS**

# %%
"Step 1 : Univariate Analysis"

# %% [markdown]
# # Understanding the distribution of the data for the quantitative attributes:
#
# 1.   Age
# 2.   Education
# 3.   Usage
# 4.   Fitness
# 5.   Income
# 6.   Miles

# %%
"Step 1.a: Outlier detection using Histogram for Quantitative columns"

# %%
fig, axis = plt.subplots(3, 2, figsize = (12,10))

sns.histplot(data=aerofit, x="Age",       kde=True, ax=axis[0,0], color = "green")
sns.histplot(data=aerofit, x="Education", kde=True, ax=axis[0,1], color = "blue")
sns.histplot(data=aerofit, x="Usage",     kde=True, ax=axis[1,0], color = "red")
sns.histplot(data=aerofit, x="Fitness",   kde=True, ax=axis[1,1], color = "pink")
sns.histplot(data=aerofit, x="Income",    kde=True, ax=axis[2,0], color = "purple")
sns.histplot(data=aerofit, x="Miles",     kde=True, ax=axis[2,1], color = "orange")
plt.show()

# %%
# Based on above graphs, we can notice the following on observation -
# 1. Outliers are found mostly in Education, Usage, Income & Miles.
# 2. Data is fairly distributed among the remaining quantitative columns i.e. Age & Fitness.
# 3. To Further validate the information, let's do boxplot.

# %%
"Step 1.b: Outlier detection using Boxplots"

# %%
fig, axis = plt.subplots(3, 2, figsize = (12,10))

sns.boxplot(data=aerofit, x="Age",       orient = "h", ax=axis[0,0], color = "green")
sns.boxplot(data=aerofit, x="Education", orient = "h", ax=axis[0,1], color = "blue")
sns.boxplot(data=aerofit, x="Usage",     orient = "h", ax=axis[1,0], color = "red")
sns.boxplot(data=aerofit, x="Fitness",   orient = "h", ax=axis[1,1], color = "pink")
sns.boxplot(data=aerofit, x="Income",    orient = "h", ax=axis[2,0], color = "purple")
sns.boxplot(data=aerofit, x="Miles",     orient = "h", ax=axis[2,1], color = "orange")
plt.show()

# %%
# Based on above graphs, we can notice now easily conclude that -
# 1. Outliers are found mostly in Income & Miles.
# 2. Data is fairly distributed among the remaining quantitative columns i.e. Age, Education, Usage & Fitness with no to minimal outliers.

# %% [markdown]
# # Understanding the distribution of the data for the qualitative attributes:
#
# 1.   Product
# 2.   Gender
# 3.   MaritalStatus

# %%
fig, axis = plt.subplots(1, 3 , figsize = (20,5))

sns.countplot(data = aerofit, x = "Product", ax=axis[0])
sns.countplot(data = aerofit, x = "Gender", ax=axis[1])
sns.countplot(data = aerofit, x = "MaritalStatus", ax=axis[2])
# Out:
# <Axes: xlabel='MaritalStatus', ylabel='count'>

# %%
# Observations:
# 1. Most sold product is KP281 which means entry-level treadmill is the most sought one by new fitness enthusiasts.
# 2. Males are more active and conscious about their fitness given more number of males in the dataset (consideration / dataset bias inferred)
# 3. Partnered people are more as per the dataset. Likely possibility, peopl are health conscious even after marriage / relationship.

# %% [markdown]
# # 4.	Representing the marginal probability like - what percent of customers have purchased KP281, KP481, or KP781 in a table

# %%
"Step 1.c: Percentage of customers purchasing 3 Products using Counts"

# %%
product_count = aerofit["Product"].value_counts().reset_index()
product_count
# Out:
#    index  Product
# 0  KP281       80
# 1  KP481       60
# 2  KP781       40

# %%
product_count.rename(columns= {"index":"Product","Product":"Product_Count"}, inplace = True)

# %%
product_count
# Out:
#   Product  Product_Count
# 0   KP281             80
# 1   KP481             60
# 2   KP781             40

# %%
product_count["Percentage_Contribution"] = product_count.apply(lambda x: np.round(((x["Product_Count"]/180)*100), decimals=2),axis=1)

# %%
product_count
# Out:
#   Product  Product_Count  Percentage_Contribution
# 0   KP281             80                    44.44
# 1   KP481             60                    33.33
# 2   KP781             40                    22.22

# %%
"Step 1.e: Percentage of customers purchasing 3 Products using Crosstabs"

# %%
aerofit_crosstab = pd.crosstab(index = aerofit["Product"],columns = aerofit["Product"], normalize = "all")
aerofit_crosstab
# Out:
# Product     KP281     KP481     KP781
# Product
# KP281    0.444444  0.000000  0.000000
# KP481    0.000000  0.333333  0.000000
# KP781    0.000000  0.000000  0.222222

# %%
plt.figure(figsize=(4,4))

plt.pie(
    x = aerofit["Product"].value_counts().values,
    labels = aerofit["Product"].value_counts().index,
    autopct = "%0.2f%%"
)
plt.show()

# %%
#Observations as below -
# 1. Products sold are in the order KP281 > KP481 > KP781
# 2. KP281 = 44.44%, KP481 = 33.33%, KP781 = 22.22%

# %%
"Step 2 : Bivariate Analysis"

# %%
"Step 2.a: Product vs. Quantitative Attributes to check effect"

# %% [markdown]
# # 3.	Check if features like marital status, age have any effect on the product purchased (using countplot, histplots, boxplots etc)
#
# For Sales analysis of Products -
#
# 1.   Which age group bought the most products and which one?
# 2.   Distinction of purchase between Male & Females.
# 3.   Is there any effect of Education on buying patten?
# 4.   Effect of Marital Status on type of product purchase.
# 5.   Trend analysis - Comparison of Product vs. Combination of Gender & Marital status.
# 6.   Usage & Fitness Trends
# 7.   Income wise distribution for each product sold
# 8.   Effect of miles on product categories.

# %%
"Age Effect on Product"

'''
Product -> Categorical
Age -> Numerical
'''

# %%
KP281_data = aerofit[aerofit["Product"]=="KP281"]
KP281_data.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %%
KP481_data = aerofit[aerofit["Product"]=="KP481"]
KP481_data.head()
# Out:
#    Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 80   KP481   19    Male         14        Single      3        3   31836
# 81   KP481   20    Male         14        Single      2        3   32973
# 82   KP481   20  Female         14     Partnered      3        3   34110
# 83   KP481   20    Male         14        Single      3        3   38658
# 84   KP481   21  Female         14     Partnered      5        4   34110
#
#     Miles
# 80     64
# 81     53
# 82    106
# 83     95
# 84    212

# %%
KP781_data = aerofit[aerofit["Product"]=="KP781"]
KP781_data.head()
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 140   KP781   22    Male         14        Single      4        3   48658
# 141   KP781   22    Male         16        Single      3        5   54781
# 142   KP781   22    Male         18        Single      4        5   48556
# 143   KP781   23    Male         16        Single      4        5   58516
# 144   KP781   23  Female         18        Single      5        4   53536
#
#      Miles
# 140    106
# 141    120
# 142    200
# 143    140
# 144    100

# %%
plt.figure(figsize=(20,10))

age_bin = [15,20,25,30,35,40,45,50]

#All Products
plt.subplot(2,3,2)
sns.histplot(data = aerofit, x = "Age", bins = age_bin, hue = "Product", kde = True)

#Product - KP281
plt.subplot(2,3,4)
sns.histplot(data = KP281_data, x = "Age", bins = age_bin, hue = "Product", kde = True)

#Product - KP481
plt.subplot(2,3,5)
sns.histplot(data = KP481_data, x = "Age", bins = age_bin, hue = "Product", kde = True)

#Product - KP781
plt.subplot(2,3,6)
sns.histplot(data = KP781_data, x = "Age", bins = age_bin, hue = "Product", kde = True)
plt.show()

# %%
#Observations by Age vs. Product:
#1. Age group of buyers are largely between age of 20 - 40 years.
#2. For Product KP281 - Largely preferred by age group 20-30, next age group prominent is 30-40.
#3. For Product KP481 - Largely preferred by age group 20-35, next set is of people in age group of 40.
#4. For Product KP781 - Largely preferred by age group 25-30, next set is of age group 20-25 & 30-35.

#Conclusion: For Aerofit to increase their revenues, should focus on age group of 20-30 more and it validates with overall stats.

# %%
"Gender Variation on Products"

'''
Product -> Categorical
Gender -> Categorical
'''

# %%
plt.figure(figsize=(20,5))

plt.subplot(1,3,1)
sns.countplot(data = aerofit, x="Gender", hue="Product", palette = "flare")
plt.title("Gender-wise Product Distribution",fontsize=20)


plt.subplot(1,3,2)
plt.pie(x = aerofit["Gender"].value_counts(),  labels=aerofit["Gender"].value_counts().index, autopct="%0.2f%%" )
plt.title("Overall Buying Preference")

plt.subplot(1,3,3)
sns.countplot(data = aerofit, x="Product", hue="Gender", palette = "flare")
plt.title("Product-wise Gender Distribution",fontsize=20)

plt.show()

# %%
#Observations by Gender vs. Product:
#1. Both genders like the product, high bias with Males.
#2. Preference of Male on average is equally distributed amongs all 3 products
#3. Preference of Femailes is highest towards KP281 and lowest towards KP781, Females don't like to buy the costliest product.

#Conclusion: For Aerofit to attract more females towards their product line, they should produce ads more female-centric often.

# %%
"Education effect on Products"

'''
Product -> Categorical
Education -> Numerical
'''

# %%
plt.figure(figsize=(20,5))

plt.subplot(1,3,1)
sns.countplot(data = aerofit, x="MaritalStatus", hue="Product", palette = "Spectral")
plt.title("MaritalStatus vs. Product Distribution",fontsize=20)


plt.subplot(1,3,2)
plt.pie(x = aerofit["MaritalStatus"].value_counts(),  labels=aerofit["MaritalStatus"].value_counts().index, autopct="%0.2f%%" )
plt.title("Overall Buying Preference")

plt.subplot(1,3,3)
sns.countplot(data = aerofit, x="Product", hue="MaritalStatus", palette = "Spectral")
plt.title("Product-wise MaritalStatus Distribution",fontsize=20)

plt.show()

# %%
#Observations by MaritalStatus vs. Product:
#1. Usage is High in case of Partnered relation vs. Single
#2. Preference for KP281 is higher followed by KP481 and KP781.
#3. Based on the Pie Graph, Interest is balanced more likely irrespective of Marital Status, but Partnered are more conscious about fitness.

#Conclusion: For Aerofit to maintain momentum on this parameter, they need to keep the excitement ongoing.

# %%
"Usage effect on Products"

'''
Product -> Categorical
Usage -> Numerical
'''

# %%
plt.figure(figsize=(20,5))

plt.subplot(1,3,1)
sns.countplot(data = aerofit, x="Usage", hue="Product", palette = "pastel")
plt.title("Usage vs. Product Distribution",fontsize=20)


plt.subplot(1,3,2)
plt.pie(x = aerofit["Usage"].value_counts(),  labels=aerofit["Usage"].value_counts().index, autopct="%0.2f%%" )
plt.title("Overall Buying Preference")

plt.subplot(1,3,3)
sns.countplot(data = aerofit, x="Product", hue="Usage", palette = "pastel")
plt.title("Product-wise Usage Distribution",fontsize=20)

plt.show()

# %%
#Observations by Usage vs. Product:
#1. Preference by Usage is highest for 3,4 and 2 times a week.
#2. For 3 times a week - 1st Preference is for KP281, followed by KP481 and KP781.
#3. For 4 times a week - 1st Preference is for KP281, interestingly KP781 is highly used followed by KP481.
#4. For 2 times a week - KP781 is not used entirely, however, KP281 and KP481 consecutively.

#Conclusion: Aerofit need to increase awareness of regular usage of their products by drawing fitness enthusiasts and influencers.

# %%
"Education effect on Products"

'''
Product -> Categorical
Fitness -> Numerical
'''

# %%
plt.figure(figsize=(20,5))

plt.subplot(1,3,1)
sns.countplot(data = aerofit, x="Fitness", hue="Product", palette = "bright")
plt.title("Fitness vs. Product Distribution",fontsize=20)


plt.subplot(1,3,2)
plt.pie(x = aerofit["Fitness"].value_counts(),  labels=aerofit["Fitness"].value_counts().index, autopct="%0.2f%%" )
plt.title("Overall Buying Preference")

plt.subplot(1,3,3)
sns.countplot(data = aerofit, x="Product", hue="Fitness", palette = "bright")
plt.title("Product-wise Fitness Distribution",fontsize=20)

plt.show()

# %%
#Observations by Usage vs. Product:
#1. Fitness Level for Aerofit Treadmills are in 3-scale with average fitness.
#2. Universe of 3-scale fitness is 54%, followed by Top fitness of 5-scale and further of under average & above average.
#3. For KP281 & KP481 - maximum users are of fitness level 3-scale.
#4. For KP781 - the highest fitness level users are active of 5-scale.

#Conclusion: It is noted that Highly fit use KP781 (top-end) product, however, average fitness can also be achieved by using KP281 & KP481

# %%
"Income effect on Products"

'''
Product -> Categorical
Income -> Numerical
'''

# %%
plt.figure(figsize=(20,10))

bin1=[20_000, 30_000, 40_000, 50_000, 60_000, 70_000, 80_000, 90_000, 10_0000, 110_000]

#Overall
plt.subplot(2,3,2)
sns.histplot(data = aerofit, x = "Income", hue = "Product", bins = bin1, kde = True)
plt.title("Product - KP281, KP481, KP781 -- Income Distribution", fontdict = {"fontsize":15})

#Product - KP281
plt.subplot(2,3,4)
sns.histplot(data = KP281_data, x = "Income", color = "green", bins = bin1, kde = True)
plt.title("Product - KP281 -- Income Distribution", fontdict = {"fontsize":20})

#Product - KP481
plt.subplot(2,3,5)
sns.histplot(data = KP481_data, x = "Income" , color = "orange" , bins = bin1, kde=True)
plt.title("Product - KP481 -- Income Distribution", fontdict = {"fontsize":20})

# #Product - KP781
plt.subplot(2,3,6)
sns.histplot(data = KP781_data, x = "Income", color = "blue", bins = bin1, kde = True)
plt.title("Product - KP781 -- Income Distribution", fontdict = {"fontsize":20})

plt.tight_layout()
plt.show()

# %%
#Observations by Income vs. Product:
#1. Overall picture shows that the Aerofit Treadmill buyers are in Income Group of 30K-60K
#2. For KP781, it is mostly bought by people with Income above 40K and highest no. of buyers are in Income range 90K-100K
#3. For KP481, most prominent buyers are in Income group of 40K-60K
#4. For KP281, it resonates the overall buying picture of people.

#Conclusion: Aerofit Treadmill across product lines is prominent among Income-Group of 40K on an average to accomodate this product in daily life.

# %%
"Miles effect on Products"

'''
Product -> Categorical
Miles -> Numerical
'''

# %%
plt.figure(figsize=(20,10))

#Overall
plt.subplot(2,3,2)
sns.histplot(data = aerofit, x = "Miles", hue = "Product", kde = True)
plt.title("Product - KP281, KP481, KP781 -- Miles Distribution", fontdict = {"fontsize":15})

#Product - KP281
plt.subplot(2,3,4)
sns.histplot(data = KP281_data, x = "Miles", color = "green", kde = True)
plt.title("Product - KP281 -- Miles Distribution", fontdict = {"fontsize":20})

#Product - KP481
plt.subplot(2,3,5)
sns.histplot(data = KP481_data, x = "Miles" , color = "orange" , kde=True)
plt.title("Product - KP481 -- Miles Distribution", fontdict = {"fontsize":20})

# #Product - KP781
plt.subplot(2,3,6)
sns.histplot(data = KP781_data, x = "Miles", color = "blue", kde = True)
plt.title("Product - KP781 -- Miles Distribution", fontdict = {"fontsize":20})

plt.tight_layout()
plt.show()

# %%
#Observations by Miles vs. Product:
#1. Overall picture shows that concentration of miles ran is between 50-100
#2. For KP781, most of number of miles ran is between 100-250, highest number of miles is 150-200
#3. For KP481, most number of miles covered mostly is between 75-125 on an average.
#4. For KP281, there is a dynamic variance of miles achieved between 40-120, highest number of miles ran is 60-80

#Conclusion: Based on each product, it is obvious that KP781(Top-end) product is judiciously used to run more miles on an average.

# %%
"Step 3 : Multi-variate Analysis"

# %%
factors = ["Age", "Education", "Usage", "Fitness", "Income", "Miles"]

#Observations

fig, axis = plt.subplots(3,2, figsize=(18, 8))

fig.subplots_adjust(top = 1.5)

count = 0

for i in range(3):
    for j in range(2):
        sns.boxplot(data = aerofit, x = "Gender", y= factors[count], hue = "Product", ax = axis[i,j])
        axis[i,j].set_title(f"Product vs {factors[count]}", pad = 12, fontsize = 10)
        count += 1

# %%
#Observations for Multivariate Analysis
#1. Mean is high amongs Males to buy KP781 as compared to other two Aerofit Treadmill products.
#2. Highly educated people irrespective of male or female bought KP781 more likely.
#3. For Usage to, KP781 is mostly used product compared to other two Aerofit products among both genders. Even fitness level is high for KP781
#4. Females planning to use Aerofit Treadmill 3-4 times a week, more likely will buy KP481.

# Conclusion: It is noted that though more educated, more Income or best fitness. KP781 is most sought product amongs all 3 products.

# %% [markdown]
# # 8.	Probability- marginal, conditional probability.
#
#
#
# For each AeroFit treadmill product, construct two-way contingency tables and compute all conditional and marginal probabilities along with their insights/impact on the business.

# %%
"Step 4 : Marginal & Conditional Probabilities"

# %%
"Marginal Probability"

# %%
aerofit["Product"].value_counts(normalize = True)
# Out:
# KP281    0.444444
# KP481    0.333333
# KP781    0.222222
# Name: Product, dtype: float64

# %%
"Produt vs. MaritalStatus - Marginal Probability"
pd.crosstab(index = aerofit["Product"], columns = aerofit["MaritalStatus"], margins = True, normalize = True)
# Out:
# MaritalStatus  Partnered    Single       All
# Product
# KP281           0.266667  0.177778  0.444444
# KP481           0.200000  0.133333  0.333333
# KP781           0.127778  0.094444  0.222222
# All             0.594444  0.405556  1.000000

# %% [markdown]
# # 6.	With all the above steps you can answer questions like: What is the probability of a male customer buying a KP781 treadmill?

# %%
"Produt vs. Gender - Marginal Probability"
pd.crosstab(index = aerofit["Product"], columns = aerofit["Gender"], margins = True, normalize = True)
# Out:
# Gender     Female      Male       All
# Product
# KP281    0.222222  0.222222  0.444444
# KP481    0.161111  0.172222  0.333333
# KP781    0.038889  0.183333  0.222222
# All      0.422222  0.577778  1.000000

# %%
#Observation: Probability of Male buying KP781 is 18.33%

# %%
"Produt vs. MaritalStatus & Gender - Marginal Probability"
pd.crosstab(index = aerofit["Product"], columns = [aerofit["MaritalStatus"], aerofit["Gender"]], margins = True, normalize = True)
# Out:
# MaritalStatus Partnered              Single                 All
# Gender           Female      Male    Female      Male
# Product
# KP281          0.150000  0.116667  0.072222  0.105556  0.444444
# KP481          0.083333  0.116667  0.077778  0.055556  0.333333
# KP781          0.022222  0.105556  0.016667  0.077778  0.222222
# All            0.255556  0.338889  0.166667  0.238889  1.000000

# %%
"Conditional Probability"

# %%
"Produt vs. MaritalStatus - Conditional Probability"
pd.crosstab(index = aerofit["Product"], columns = aerofit["MaritalStatus"], margins = True, normalize = "columns")
# Out:
# MaritalStatus  Partnered    Single       All
# Product
# KP281           0.448598  0.438356  0.444444
# KP481           0.336449  0.328767  0.333333
# KP781           0.214953  0.232877  0.222222

# %%
"Produt vs. Gender - Conditional Probability"
pd.crosstab(index = aerofit["Product"], columns = aerofit["Gender"], margins = True, normalize = "columns")
# Out:
# Gender     Female      Male       All
# Product
# KP281    0.526316  0.384615  0.444444
# KP481    0.381579  0.298077  0.333333
# KP781    0.092105  0.317308  0.222222

# %%
"Produt vs. Gender & MaritalStatus - Conditional Probability"
pd.crosstab(index = aerofit["Product"], columns = [aerofit["MaritalStatus"], aerofit["Gender"]], margins = True, normalize = "columns")
# Out:
# MaritalStatus Partnered              Single                 All
# Gender           Female      Male    Female      Male
# Product
# KP281          0.586957  0.344262  0.433333  0.441860  0.444444
# KP481          0.326087  0.344262  0.466667  0.232558  0.333333
# KP781          0.086957  0.311475  0.100000  0.325581  0.222222

# %% [markdown]
# # 5.	Check correlation among different factors using heat maps or pair plots.

# %%
"Step 1 - Correlation"

# %%
aerofit_numerical = aerofit.select_dtypes(include = "number")
aerofit_numerical
# Out:
#      Age  Education  Usage  Fitness  Income  Miles
# 0     18         14      3        4   29562    112
# 1     19         15      2        3   31836     75
# 2     19         14      4        3   30699     66
# 3     19         12      3        3   32973     85
# 4     20         13      4        2   35247     47
# ..   ...        ...    ...      ...     ...    ...
# 175   40         21      6        5   83416    200
# 176   42         18      5        4   89641    200
# 177   45         16      5        5   90886    160
# 178   47         18      4        5  104581    120
# 179   48         18      4        5   95508    180
#
# [180 rows x 6 columns]

# %%
aerofit_numerical.corr()
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %%
sns.heatmap(data = aerofit_numerical.corr(), cmap="Reds", annot = True)
# Out:
# <Axes: >

# %%
#Observations:
#1. Strong Correlation: a. Fitness & Miles = 0.79, b. Miles & Usage = 0.76, c. Fitness & Usage = 0.67
#2. Weak Correlation:   a. Age & Usage = 0.015,    b. Age & Miles = 0.037,  c. Age & Fitness = 0.061

# %% [markdown]
# # **From various observations, we can make a customer profile for particular products:**

# %% [markdown]
# # KP281 :
#
# *   Most affordable and entry level and Maximum Selling Product.
# *   This model popular amongst both Male and Female customers
# *   Same number of Male and Female customers.
# *   Customers walk/run average 70 to 90 miles on this product.
# *   Customers use 3 to 4 times a week
# *   Fitness Level of this product users is Average Shape.
# *   More general purpose for all age group and fitness levels.
#
#
# # KP481 :
#
# *   Intermediate Price Range
# *   Fitness Level of this product users varies from Bad to Average Shape depending on their usage.
# *   Customers prefer KP481 model to use less frequent but to run more miles per week on this.
# *   Customer walk/run average 70 to 130 or more miles per week on his product.
# *   Probability of Female customer buying KP481 is significantly higher than male.
# *   KP481 product is specifically recommended for Female customers who are intermediate user.
# *   customers are from adult, teen and mid-age categories.
#
#
# # KP781 :
#
# *   least sold product but highly effective
# *   high price and preferred by customers who does exercises more extensively and run more miles.
# *   Customer walk/run average 120 to 200 or more miles per week on his product.
# *   If person is in Excellent Shape , the probability that he is using KP781 is more than 90%.
# *   Female Customers who are running average 180 miles (extensive exercise) , are using product KP781, which is higher than Male average using same product.
# *   KP781 can be recommended for Female customers who exercises extensively.
# *   Probability of Male customer buying Product KP781(31.73%) is way more than female(9.21%).
# *   Probability of a single person buying KP781 is higher than Married customers. So , KP781 is also recommended for people who are single and exercises more.
# *   most of old people who are above 45 age and adult uses this product.

# %% [markdown]
# # **Recommendations :**
#
# *   Recommend KP781 product to users who runs more frequently and run more miles , and have high income. Since KP781 is least selling product (22.2% share of all the products) , recommend this product some customers who exercise at intermediate to extensive level , if they are planning to go for KP481. Also the targeted Age Category is Adult and age above 45.
# *   Recommend KP481 product for female customers who runs more miles, as data shows their probability is higher. Statistical Summery about fitness level and miles for KP481 is not good as KP281 which is cheaper product. Possibly because of price, customers prefer to purchase KP281. It is recommended to make some necessary changes to product K481 to increase customer experience.
